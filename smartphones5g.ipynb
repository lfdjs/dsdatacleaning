# %%
#Notebook com finalidade para análise de dados de celulares 5G hoologados pela anatel


import pandas as pd
import seaborn as srn
import statistics  as sts

# %%
#importar dados
dataset = pd.read_csv("celulares_5g_homologados.csv", sep=";")

dataset
# Out:
#      NumeroHomologacao DataEmissaoHomologacao           TipodeProduto  \
# 0         219902200953             2023-02-17  Telefone Móvel Celular
# 1         219892200953             2023-02-27  Telefone Móvel Celular
# 2         217652209185             2023-02-02  Telefone Móvel Celular
# 3         217652209185             2023-02-02  Telefone Móvel Celular
# 4         217592209185             2023-03-03  Telefone Móvel Celular
# ..                 ...                    ...                     ...
# 108         4002213366             2022-03-07  Telefone Móvel Celular
# 109         3792000330             2022-02-11  Telefone Móvel Celular
# 110         2822200953             2022-03-09  Telefone Móvel Celular
# 111         1472314550             2023-03-03  Telefone Móvel Celular
# 112          512201993             2023-02-13  Telefone Móvel Celular
#
#            Modelo       NomeComercial        ModoOperacao5G  \
# 0    SM-A346M/DSN                 NaN      Ambos (SA / NSA)
# ...
