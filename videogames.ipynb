# %%
import pandas as pd
import seaborn as srn
import statistics  as sts

# %%
#importar dados
dataset = pd.read_csv("vgsales.csv", sep=",")
#dataset.columns = ["Posição", "Nome","Plataforma","Ano de Lançamento","Genero","Publicação","Vendas na América do Norte","Vendas na Europa","Vendas no Japão","Outras Vendas",
 #                   "Vendas Globais"]
#visulizar
dataset.head(100)
# Out:
#     Rank                                    Name Platform    Year  \
# 0      1                              Wii Sports      Wii  2006.0
# 1      2                       Super Mario Bros.      NES  1985.0
# 2      3                          Mario Kart Wii      Wii  2008.0
# 3      4                       Wii Sports Resort      Wii  2009.0
# 4      5                Pokemon Red/Pokemon Blue       GB  1996.0
# ..   ...                                     ...      ...     ...
# 95    96  Crash Bandicoot 2: Cortex Strikes Back       PS  1997.0
# 96    97                     Super Mario Bros. 2      NES  1988.0
# 97    98     Super Smash Bros. for Wii U and 3DS      3DS  2014.0
# 98    99              Call of Duty: World at War     X360  2008.0
# 99   100                           Battlefield 3     X360  2011.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports                     Nintendo     41.49     29.02      3.77
# ...

# %%
#explorar dados categoricos
#Platform
agrupado = dataset.groupby(['Platform']).size()
agrupado
# Out:
# Platform
# 2600     133
# 3DO        3
# 3DS      509
# DC        52
# DS      2163
# GB        98
# GBA      822
# GC       556
# GEN       27
# GG         1
# N64      319
# NES       98
# NG        12
# PC       960
# PCFX       1
# PS      1196
# PS2     2161
# PS3     1329
# PS4      336
# PSP     1213
# PSV      413
# SAT      173
# SCD        6
# SNES     239
# TG16       2
# WS         6
# Wii     1325
# WiiU     143
# X360    1265
# XB       824
# XOne     213
# dtype: int64

# %%
#Publisher
agrupado = dataset.groupby(['Publisher']).size()
agrupado
# Out:
# Publisher
# 10TACLE Studios                  3
# 1C Company                       3
# 20th Century Fox Video Games     5
# 2D Boy                           1
# 3DO                             36
#                                 ..
# id Software                      1
# imageepoch Inc.                  2
# inXile Entertainment             1
# mixi, Inc                        1
# responDESIGN                     2
# Length: 578, dtype: int64

# %%
agrupado.plot.bar(color = 'gray')
# Out:
# <AxesSubplot: xlabel='Platform'>

# %%
dataset['Global_Sales'].describe()
# Out:
# count    16598.000000
# mean         0.537441
# std          1.555028
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %%
srn.boxplot(dataset['Global_Sales']).set_title('Vendas Globais')
# Out:
# Text(0.5, 1.0, 'Vendas Globais')

# %%
#verificar Anos vazios
dataset[dataset['Year'].isnull()].head(100)
# Out:
#       Rank                          Name       Platform  Year     Genre  \
# 179    180               Madden NFL 2004  PlayStation 2   NaN    Sports
# 377    378              FIFA Soccer 2004  PlayStation 2   NaN    Sports
# 431    432    LEGO Batman: The Videogame            Wii   NaN    Action
# 470    471    wwe Smackdown vs. Raw 2006  PlayStation 2   NaN  Fighting
# 607    608                Space Invaders           2600   NaN   Shooter
# ...    ...                           ...            ...   ...       ...
# 6283  6285                      Indy 500           2600   NaN    Racing
# 6314  6316                           Gun       Xbox 360   NaN   Shooter
# 6316  6318                  Flag Capture           2600   NaN    Action
# 6319  6321  LEGO Harry Potter: Years 5-7            PSP   NaN    Action
# 6401  6403               Rock Revolution  PlayStation 3   NaN      Misc
#
#                                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Year
#Verificar anos vazios
dataset.groupby(['Publisher']).size().isnull()
# Out:
# Publisher
# 10TACLE Studios                 False
# 1C Company                      False
# 20th Century Fox Video Games    False
# 2D Boy                          False
# 3DO                             False
#                                 ...
# id Software                     False
# imageepoch Inc.                 False
# inXile Entertainment            False
# mixi, Inc                       False
# responDESIGN                    False
# Length: 578, dtype: bool

# %%
#verificar Publishers vazios
dataset[dataset['Publisher'].isnull()].tail(50)
# Out:
#         Rank                                               Name  \
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...
# 6272    6274  The Legend of Zelda: The Minish Cap(weekly JP ...
# 6437    6439           Sonic X: Game Boy Advance Video Volume 1
# 6562    6564  Dora the Explorer: Game Boy Advance Video Volu...
# 6648    6650  Cartoon Network Collection: Game Boy Advance V...
# 6849    6851     All Grown Up!: Game Boy Advance Video Volume 1
# 7208    7210  Nicktoons Collection: Game Boy Advance Video V...
# 7351    7353                     Yu Yu Hakusho: Dark Tournament
# 7470    7472  SpongeBob SquarePants: Game Boy Advance Video ...
# 7953    7955                   Thomas the Tank Engine & Friends
# 8330    8332    Dragon Ball GT: Game Boy Advance Video Volume 1
# ...

# %%
#alterando nomes dos consoles
dataset.loc[dataset['Platform'] ==  'PS', 'Platform'] = "PlayStation"
dataset.loc[dataset['Platform'] ==  'PS2', 'Platform'] = "PlayStation 2"
dataset.loc[dataset['Platform'] ==  'PS3', 'Platform'] = "PlayStation 3"
dataset.loc[dataset['Platform'] ==  'PS4', 'Platform'] = "PlayStation 4"
dataset.loc[dataset['Platform'] ==  'GBA', 'Platform'] = "Game Boy Advance"
dataset.loc[dataset['Platform'] ==  'DS', 'Platform'] = "Nintendo DS"
dataset.loc[dataset['Platform'] ==  'X360', 'Platform'] = "Xbox 360"
dataset.loc[dataset['Platform'] ==  '3DS', 'Platform'] = "Nintendo 3DS"
dataset.loc[dataset['Platform'] ==  'XOne', 'Platform'] = "Xbox One"
dataset.loc[dataset['Platform'] ==  'GB', 'Platform'] = "Game Boy"

# %%
#Verificando os jogos mais vendidos 
dataset[dataset['Platform'] == "SNES"].head(20)
# Out:
#      Rank                                               Name Platform    Year  \
# 18     19                                  Super Mario World     SNES  1990.0
# 57     58                              Super Mario All-Stars     SNES  1993.0
# 71     72                                Donkey Kong Country     SNES  1994.0
# 76     77                                   Super Mario Kart     SNES  1992.0
# 136   137               Street Fighter II: The World Warrior     SNES  1992.0
# 187   188          Donkey Kong Country 2: Diddy's Kong Quest     SNES  1995.0
# 231   232            The Legend of Zelda: A Link to the Past     SNES  1991.0
# 282   283                Super Mario World 2: Yoshi's Island     SNES  1995.0
# 285   286                            Street Fighter II Turbo     SNES  1992.0
# 372   373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  1996.0
# 389   390                                  Final Fantasy III     SNES  1994.0
# ...
